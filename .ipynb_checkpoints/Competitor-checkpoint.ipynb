# %% [markdown]
# <details>
#     <summary>Competitor Data</summary>
# </details>

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sb
import warnings
warnings.filterwarnings('ignore')

# %%
#Read data
df = pd.read_csv("competitor_campaigns.csv")
df.head()
# Out:
#   Competitor ID  Campaign ID  Ad Spend  Impressions  Clicks  Conversions  \
# 0  Competitor A            1      1373       432495   24027         3003
# 1  Competitor C            2      1275       455175   45517         5057
# 2  Competitor B            3      1406       940614   52256         3483
# 3  Competitor A            4      1820      1126580   62587         6258
# 4  Competitor C            5      1216       464512   27324         3036
#
#      Sales Campaign Start Date Campaign End Date
# 0   786786          2023-07-02        2023-07-07
# 1   338819          2023-09-03        2023-09-05
# 2   257742          2023-05-14        2023-05-25
# 3  1983786          2023-06-22        2023-07-16
# 4   789360          2023-11-16        2023-12-04

# %%
# Data Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Competitor ID        100 non-null    object
#  1   Campaign ID          100 non-null    int64
#  2   Ad Spend             100 non-null    int64
#  3   Impressions          100 non-null    int64
#  4   Clicks               100 non-null    int64
#  5   Conversions          100 non-null    int64
#  6   Sales                100 non-null    int64
#  7   Campaign Start Date  100 non-null    object
#  8   Campaign End Date    100 non-null    object
# dtypes: int64(6), object(3)
# memory usage: 7.2+ KB

# %%
# Check for missing data
df.isna().sum()
# Out:
# Competitor ID          0
# Campaign ID            0
# Ad Spend               0
# Impressions            0
# Clicks                 0
# Conversions            0
# Sales                  0
# Campaign Start Date    0
# Campaign End Date      0
# dtype: int64

# %%
#df[["Campaign Start Date", "Campaign End Date"]] = pd.to_datetime(df[["Campaign Start Date", "Campaign End Date"]])
#df.tail()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df[["Campaign Start Date", "Campaign End Date"]] = pd.to_datetime(df[["Campaign Start Date", "Campaign End Date"]])
#       2 df.tail()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1115, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1113         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1114 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# -> 1115     result = _assemble_from_unit_mappings(arg, errors, utc)
#    1116 elif isinstance(arg, Index):
#    1117     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1231, in _assemble_from_unit_mappings(arg, errors, utc)
#    1229 if len(req):
#    1230     _required = ",".join(req)
# -> 1231     raise ValueError(
#    1232         "to assemble mappings requires at least that "
#    1233         f"[year, month, day] be specified: [{_required}] is missing"
#    1234     )
#    1236 # keys we don't recognize
#    1237 excess = sorted(set(unit_rev.keys()) - set(_unit_map.values()))
#
# ValueError: to assemble mappings requires at least that [year, month, day] be specified: [day,month,year] is missing

# %%
k = "Hello World"
k.split(" ")
# Out:
# ['Hello', 'World']

# %%
y = df['Campaign Start Date'].str.split("-", expand=True)
y.head()
# Out:
#       0   1   2
# 0  2023  07  02
# 1  2023  09  03
# 2  2023  05  14
# 3  2023  06  22
# 4  2023  11  16

# %%
df['Campaign Start Date'] =y[1]+"/"+y[2]+"/"+y[0]
df.head()
# Out:
#   Competitor ID  Campaign ID  Ad Spend  Impressions  Clicks  Conversions  \
# 0  Competitor A            1      1373       432495   24027         3003
# 1  Competitor C            2      1275       455175   45517         5057
# 2  Competitor B            3      1406       940614   52256         3483
# 3  Competitor A            4      1820      1126580   62587         6258
# 4  Competitor C            5      1216       464512   27324         3036
#
#      Sales Campaign Start Date Campaign End Date
# 0   786786          07/02/2023        2023-07-07
# 1   338819          09/03/2023        2023-09-05
# 2   257742          05/14/2023        2023-05-25
# 3  1983786          06/22/2023        2023-07-16
# 4   789360          11/16/2023        2023-12-04

# %%
k = df['Campaign End Date'].str.split('-', expand=True)
df['Campaign End Date'] = k[1] + "/" + k[2] +"/"+k[0]
df.tail()
# Out:
#    Competitor ID  Campaign ID  Ad Spend  Impressions  Clicks  Conversions  \
# 95  Competitor B           96       650       458900   41718         3792
# 96  Competitor C           97      1228      1200984   70646        11774
# 97  Competitor C           98      1746      1534734   85263        14210
# 98  Competitor B           99       775       727725   38301         2946
# 99  Competitor A          100      1370       632940   48687         8114
#
#       Sales Campaign Start Date Campaign End Date
# 95  1190688          04/14/2023        04/21/2023
# 96  3438008          06/08/2023        06/16/2023
# 97  5499270          02/22/2023        03/01/2023
# 98   730608          07/26/2023        07/28/2023
# 99  4024544          03/07/2023        03/31/2023

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Competitor ID        100 non-null    object
#  1   Campaign ID          100 non-null    int64
#  2   Ad Spend             100 non-null    int64
#  3   Impressions          100 non-null    int64
#  4   Clicks               100 non-null    int64
#  5   Conversions          100 non-null    int64
#  6   Sales                100 non-null    int64
#  7   Campaign Start Date  100 non-null    object
#  8   Campaign End Date    100 non-null    object
# dtypes: int64(6), object(3)
# memory usage: 7.2+ KB

# %%
df["Campaign Start Date"] = pd.to_datetime(df["Campaign Start Date"])

# %%
df["Campaign End Date"] = pd.to_datetime(df["Campaign End Date"])
df.tail()
# Out:
#    Competitor ID  Campaign ID  Ad Spend  Impressions  Clicks  Conversions  \
# 95  Competitor B           96       650       458900   41718         3792
# 96  Competitor C           97      1228      1200984   70646        11774
# 97  Competitor C           98      1746      1534734   85263        14210
# 98  Competitor B           99       775       727725   38301         2946
# 99  Competitor A          100      1370       632940   48687         8114
#
#       Sales Campaign Start Date Campaign End Date
# 95  1190688          2023-04-14        2023-04-21
# 96  3438008          2023-06-08        2023-06-16
# 97  5499270          2023-02-22        2023-03-01
# 98   730608          2023-07-26        2023-07-28
# 99  4024544          2023-03-07        2023-03-31

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Competitor ID        100 non-null    object
#  1   Campaign ID          100 non-null    int64
#  2   Ad Spend             100 non-null    int64
#  3   Impressions          100 non-null    int64
#  4   Clicks               100 non-null    int64
#  5   Conversions          100 non-null    int64
#  6   Sales                100 non-null    int64
#  7   Campaign Start Date  100 non-null    datetime64[ns]
#  8   Campaign End Date    100 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), int64(6), object(1)
# memory usage: 7.2+ KB

# %%
df["Competitor ID"].unique()
# Out:
# array(['Competitor A', 'Competitor C', 'Competitor B'], dtype=object)

# %%
df['Competitor ID'].value_counts()
# Out:
# Competitor ID
# Competitor C    46
# Competitor B    33
# Competitor A    21
# Name: count, dtype: int64

# %%
df['Competitor ID'].value_counts().sort_values(ascending=True)
# Out:
# Competitor ID
# Competitor A    21
# Competitor B    33
# Competitor C    46
# Name: count, dtype: int64

# %%
df['Campaign ID'].nunique()
# Out:
# 100

# %%
fig, ax = plt.subplots(figsize=[4,3])
ax.scatter(df["Campaign Start Date"], df['Sales'])

# %%
df2 = df.copy()

# %%
df2.head()
# Out:
#   Competitor ID  Campaign ID  Ad Spend  Impressions  Clicks  Conversions  \
# 0  Competitor A            1      1373       432495   24027         3003
# 1  Competitor C            2      1275       455175   45517         5057
# 2  Competitor B            3      1406       940614   52256         3483
# 3  Competitor A            4      1820      1126580   62587         6258
# 4  Competitor C            5      1216       464512   27324         3036
#
#      Sales Campaign Start Date Campaign End Date
# 0   786786          2023-07-02        2023-07-07
# 1   338819          2023-09-03        2023-09-05
# 2   257742          2023-05-14        2023-05-25
# 3  1983786          2023-06-22        2023-07-16
# 4   789360          2023-11-16        2023-12-04

# %%
df2.index = df['Campaign Start Date']

# %%
df2.head()
# Out:
#                     Competitor ID  Campaign ID  Ad Spend  Impressions  Clicks  \
# Campaign Start Date
# 2023-07-02           Competitor A            1      1373       432495   24027
# 2023-09-03           Competitor C            2      1275       455175   45517
# 2023-05-14           Competitor B            3      1406       940614   52256
# 2023-06-22           Competitor A            4      1820      1126580   62587
# 2023-11-16           Competitor C            5      1216       464512   27324
#
#                      Conversions    Sales Campaign Start Date  \
# Campaign Start Date
# 2023-07-02                  3003   786786          2023-07-02
# 2023-09-03                  5057   338819          2023-09-03
# 2023-05-14                  3483   257742          2023-05-14
# 2023-06-22                  6258  1983786          2023-06-22
# 2023-11-16                  3036   789360          2023-11-16
#
#                     Campaign End Date
# Campaign Start Date
# 2023-07-02                 2023-07-07
# 2023-09-03                 2023-09-05
# 2023-05-14                 2023-05-25
# 2023-06-22                 2023-07-16
# 2023-11-16                 2023-12-04

# %%
df2.plot('Sales')
# Out:
# <Axes: xlabel='Sales'>

# %%
df['Sales'].cumsum().plot()
# Out:
# <Axes: >

# %%
df['Sales'].cumsum()
# Out:
# 0        786786
# 1       1125605
# 2       1383347
# 3       3367133
# 4       4156493
#         ...
# 95    140255403
# 96    143693411
# 97    149192681
# 98    149923289
# 99    153947833
# Name: Sales, Length: 100, dtype: int64

# %%
df2['Sales'].cumsum().plot()
plt.title("Sales Campaign Start Date")
plt.xlabel("Start Date For Campaign")
plt.ylabel('Sales')
plt.legend()

# %% [markdown]
# <h2>Matplotlib</h2>

# %%
plt.plot(df['Sales'])

# %%
plt.hist(df['Sales'], bins=50);

# %%
plt.boxplot(df['Impressions']);

# %%
df2.Sales.nunique()
# Out:
# 100

# %%
df2.describe().T
# Out:
#                      count                 mean                  min  \
# Campaign ID          100.0                 50.5                  1.0
# Ad Spend             100.0              1272.58                575.0
# Impressions          100.0             753573.7             106080.0
# Clicks               100.0             52268.05               5583.0
# Conversions          100.0              5774.51                398.0
# Sales                100.0           1539478.33              85373.0
# Campaign Start Date    100  2023-07-08 12:43:12  2023-01-07 00:00:00
# Campaign End Date      100  2023-07-23 12:57:36  2023-01-11 00:00:00
#
#                                      25%                  50%  \
# Campaign ID                        25.75                 50.5
# Ad Spend                          1013.5               1267.5
# Impressions                     417633.0             700441.0
# Clicks                          28818.75              45740.0
# Conversions                      2961.75               4918.0
# Sales                           594816.0            1131468.5
# Campaign Start Date  2023-04-13 00:00:00  2023-07-01 12:00:00
# Campaign End Date    2023-04-27 18:00:00  2023-07-18 12:00:00
#
#                                      75%                  max             std
# Campaign ID                        75.25                100.0       29.011492
# Ad Spend                          1577.5               1972.0      389.009729
# Impressions                    1078374.0            1751588.0   422861.435151
# Clicks                          70673.75             154644.0       32338.556
# Conversions                      8031.75              23354.0       4143.6358
# Sales                         2160520.25            6375642.0  1323090.003391
# Campaign Start Date  2023-10-11 00:00:00  2023-12-28 00:00:00             NaN
# Campaign End Date    2023-10-23 00:00:00  2024-01-17 00:00:00             NaN

# %%
df.head()
# Out:
#   Competitor ID  Campaign ID  Ad Spend  Impressions  Clicks  Conversions  \
# 0  Competitor A            1      1373       432495   24027         3003
# 1  Competitor C            2      1275       455175   45517         5057
# 2  Competitor B            3      1406       940614   52256         3483
# 3  Competitor A            4      1820      1126580   62587         6258
# 4  Competitor C            5      1216       464512   27324         3036
#
#      Sales Campaign Start Date Campaign End Date
# 0   786786          2023-07-02        2023-07-07
# 1   338819          2023-09-03        2023-09-05
# 2   257742          2023-05-14        2023-05-25
# 3  1983786          2023-06-22        2023-07-16
# 4   789360          2023-11-16        2023-12-04

# %%
df.index = df['Campaign End Date']

# %%
df.head()
# Out:
#                   Competitor ID  Campaign ID  Ad Spend  Impressions  Clicks  \
# Campaign End Date
# 2023-07-07         Competitor A            1      1373       432495   24027
# 2023-09-05         Competitor C            2      1275       455175   45517
# 2023-05-25         Competitor B            3      1406       940614   52256
# 2023-07-16         Competitor A            4      1820      1126580   62587
# 2023-12-04         Competitor C            5      1216       464512   27324
#
#                    Conversions    Sales Campaign Start Date Campaign End Date
# Campaign End Date
# 2023-07-07                3003   786786          2023-07-02        2023-07-07
# 2023-09-05                5057   338819          2023-09-03        2023-09-05
# 2023-05-25                3483   257742          2023-05-14        2023-05-25
# 2023-07-16                6258  1983786          2023-06-22        2023-07-16
# 2023-12-04                3036   789360          2023-11-16        2023-12-04

# %%
df['Impressions'].plot()
# Out:
# <Axes: xlabel='Campaign End Date'>

# %% [markdown]
# <details>
#     <summary>Numerical data manipulation factors</summary>
# </details>
# <ul>
#     <li>Center</li>
#     <li>Spread</li>
#     <li>Shape</li>
#     <li>Outliers</li>
# </ul>

# %% [markdown]
# <h2>Center</h2>
# <ul>
#     <li>Mean</li>
#     <li>Median</li>
#     <li>Mode</li>
# </ul>

# %%
df['Sales'].mean()
# Out:
# 1539478.33

# %%
df['Sales'].mode()
# Out:
# 0       85373
# 1      103770
# 2      111024
# 3      125341
# 4      134922
#        ...
# 95    4362058
# 96    4570968
# 97    5281380
# 98    5499270
# 99    6375642
# Name: Sales, Length: 100, dtype: int64

# %%
df.Sales.median()
# Out:
# 1131468.5

# %% [markdown]
# <h2>Spread</h2>
# <ul>
#     <li>Range</li>
#     <li>Interquantile range</li>
#     <li>Standard deviation</li>
#     <li>Variance</li>
# </ul>

# %%
df3 = df[['Ad Spend','Impressions','Clicks','Conversions','Sales']]

# %%
[low, high] = df3['Sales'].quantile([.1, .5])

# %%
round(low, 2) , round(high, 2)
# Out:
# (318526.1, 1131468.5)

# %%
df4 = df3[df3['Sales'].between(low, high)]
df4.head()
# Out:
#                    Ad Spend  Impressions  Clicks  Conversions   Sales
# Campaign End Date
# 2023-07-07             1373       432495   24027         3003  786786
# 2023-09-05             1275       455175   45517         5057  338819
# 2023-12-04             1216       464512   27324         3036  789360
# 2023-03-02              722       327066   16353         2044  533484
# 2024-01-09              861       854973   61069         8724  549612

# %%
df4.size
# Out:
# 200

# %% [markdown]
# <p>&#8721;</p>

# %%
df4.describe().T
# Out:
#              count        mean            std       min        25%       50%  \
# Ad Spend      40.0    1207.175     396.697061     575.0     919.50    1225.0
# Impressions   40.0  600992.100  315122.240801  128643.0  345975.75  584107.0
# Clicks        40.0   38582.425   20387.754389    8576.0   24705.75   36801.5
# Conversions   40.0    4036.550    2752.966931     775.0    2202.25    3073.0
# Sales         40.0  678134.475  219794.335518  321625.0  545580.00  634792.0
#
#                    75%        max
# Ad Spend       1440.00     1972.0
# Impressions  795939.25  1680480.0
# Clicks        45983.75    93360.0
# Conversions    5089.50    13337.0
# Sales        792375.00  1128337.0

# %%
df4.var()
# Out:
# Ad Spend       1.573686e+05
# Impressions    9.930203e+10
# Clicks         4.156605e+08
# Conversions    7.578827e+06
# Sales          4.830955e+10
# dtype: float64

# %% [markdown]
# <h2>Shape</h2>

# %%
df3.shape, df3.size, df3.ndim
# Out:
# ((100, 5), 500, 2)

# %% [markdown]
# <h2>Outliers</h2>

# %%
df3.describe().T
# Out:
#              count        mean           std       min        25%        50%  \
# Ad Spend     100.0     1272.58  3.890097e+02     575.0    1013.50     1267.5
# Impressions  100.0   753573.70  4.228614e+05  106080.0  417633.00   700441.0
# Clicks       100.0    52268.05  3.233856e+04    5583.0   28818.75    45740.0
# Conversions  100.0     5774.51  4.143636e+03     398.0    2961.75     4918.0
# Sales        100.0  1539478.33  1.323090e+06   85373.0  594816.00  1131468.5
#
#                     75%        max
# Ad Spend        1577.50     1972.0
# Impressions  1078374.00  1751588.0
# Clicks         70673.75   154644.0
# Conversions     8031.75    23354.0
# Sales        2160520.25  6375642.0

# %%
df_m = pd.read_csv('external_factors.csv')
df_m.head()
# Out:
#          Date  GDP Growth Rate (%)  Inflation Rate (%)  \
# 0  2023-01-01             1.299856            2.001257
# 1  2023-01-02             0.882339            1.179318
# 2  2023-01-03             1.294174            2.604552
# 3  2023-01-04             1.394503            2.033785
# 4  2023-01-05             1.207972            1.861191
#
#    Consumer Sentiment Index             Industry Trends
# 0                        71        Market consolidation
# 1                        77        Sustainability focus
# 2                       104  Emerging technology trends
# 3                        82        Sustainability focus
# 4                        72        Market consolidation

# %%
df_m.describe().T
# Out:
#                           count       mean        std        min        25%  \
# GDP Growth Rate (%)       365.0   1.501795   0.579082   0.504512   1.024301
# Inflation Rate (%)        365.0   1.992447   0.578246   1.002607   1.552161
# Consumer Sentiment Index  365.0  89.915068  12.161953  70.000000  79.000000
#
#                                 50%         75%         max
# GDP Growth Rate (%)        1.472418    2.001695    2.497657
# Inflation Rate (%)         1.953305    2.462615    2.991162
# Consumer Sentiment Index  89.000000  102.000000  110.000000

# %% [markdown]
# <h2>Categorical Analysis</h2>

# %%
df.describe(include="object")
# Out:
#        Competitor ID
# count            100
# unique             3
# top     Competitor C
# freq              46

# %%
df['Competitor ID'].value_counts()
# Out:
# Competitor ID
# Competitor C    46
# Competitor B    33
# Competitor A    21
# Name: count, dtype: int64

# %%
df['Competitor ID'].value_counts().sort_values(ascending=True)
# Out:
# Competitor ID
# Competitor A    21
# Competitor B    33
# Competitor C    46
# Name: count, dtype: int64

# %%
df_cust = pd.read_csv('customers.csv')

# %%
df_cust.head()
# Out:
#    Customer ID  Age  Gender     Location Customer Segment
# 0            1   25  Female  Los Angeles          Premium
# 1            2   49  Female     New York              New
# 2            3   51  Female  Los Angeles          Regular
# 3            4   44    Male      Chicago          Regular
# 4            5   61  Female      Chicago              New

# %%
df_cust.Location.unique()
# Out:
# array(['Los Angeles', 'New York', 'Chicago', 'San Francisco'],
#       dtype=object)

# %%
df_cust.shape
# Out:
# (100, 5)

# %%
df_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer ID       100 non-null    int64
#  1   Age               100 non-null    int64
#  2   Gender            100 non-null    object
#  3   Location          100 non-null    object
#  4   Customer Segment  100 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 4.0+ KB

# %%
df_cust.Location.value_counts()
# Out:
# Location
# Chicago          35
# Los Angeles      27
# San Francisco    20
# New York         18
# Name: count, dtype: int64

# %%
df_cust.groupby('Location')['Age'].max()
# Out:
# Location
# Chicago          64
# Los Angeles      64
# New York         63
# San Francisco    65
# Name: Age, dtype: int64

# %%
df_cust.Gender.value_counts()
# Out:
# Gender
# Female    36
# Other     33
# Male      31
# Name: count, dtype: int64

# %%
df_cust.describe(include="object")
# Out:
#         Gender Location Customer Segment
# count      100      100              100
# unique       3        4                3
# top     Female  Chicago          Regular
# freq        36       35               38

# %%
df_cust['Customer Segment'].unique()
# Out:
# array(['Premium', 'New', 'Regular'], dtype=object)

# %%
pd.crosstab(df_cust['Customer Segment'], df_cust['Location'])
# Out:
# Location          Chicago  Los Angeles  New York  San Francisco
# Customer Segment
# New                    15            7         3              6
# Premium                 8           10         5              8
# Regular                12           10        10              6

# %%
(pd.crosstab(df_cust['Customer Segment'], df_cust['Location'])).plot(kind="bar")
# Out:
# <Axes: xlabel='Customer Segment'>

# %%
sb.countplot( x=df_cust["Location"], hue=df_cust["Gender"])
# Out:
# <Axes: xlabel='Location', ylabel='count'>

# %%
plt.pie(df_cust['Age']);

# %%
df_m['Consumer Sentiment Index'].nunique()
# Out:
# 41

# %%
plt.pie(df_m['Consumer Sentiment Index']);

# %%
y = df_cust['Customer Segment'].str.replace("Premium", "3").str.replace('New', "1").str.replace("Regular", "2").astype('int64')

# %%
y.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
y.value_counts()
# Out:
# Customer Segment
# 2    38
# 3    31
# 1    31
# Name: count, dtype: int64

# %%
plt.pie(y.value_counts(), labels=["Regular","Premium","New"], colors=['red','pink','black']);
